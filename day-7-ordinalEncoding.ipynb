# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
df = pd.read_csv("customer.csv")

# %%
df=df.iloc[:,2:]

# %%
df
# Out:
#      review education purchased
# 0   Average    School        No
# 1      Poor        UG        No
# 2      Good        PG        No
# 3      Good        PG        No
# 4   Average        UG        No
# 5   Average    School       Yes
# 6      Good    School        No
# 7      Poor    School       Yes
# 8   Average        UG        No
# 9      Good        UG       Yes
# 10     Good        UG       Yes
# 11     Good        UG       Yes
# 12     Poor    School        No
# 13  Average    School        No
# 14     Poor        PG       Yes
# 15     Poor        UG        No
# 16     Poor        UG       Yes
# 17     Poor        UG       Yes
# 18     Good    School        No
# 19     Poor        PG       Yes
# 20  Average    School       Yes
# 21  Average        PG        No
# 22     Poor        PG       Yes
# 23     Good    School        No
# 24  Average        PG       Yes
# 25     Good    School        No
# 26     Poor        PG        No
# 27     Poor        PG        No
# 28     Poor    School        No
# 29  Average        UG       Yes
# 30  Average        UG        No
# 31     Poor    School       Yes
# 32  Average        UG       Yes
# 33     Good        PG       Yes
# 34  Average    School        No
# 35     Poor    School       Yes
# 36     Good        UG       Yes
# 37  Average        PG       Yes
# 38     Good    School        No
# 39     Poor        PG        No
# 40     Good    School        No
# 41     Good        PG       Yes
# 42     Good        PG       Yes
# 43     Poor        PG        No
# 44  Average        UG        No
# 45     Poor        PG       Yes
# 46     Poor        PG        No
# 47     Good        PG       Yes
# 48     Good        UG       Yes
# 49     Good        UG        No

# %%
from sklearn.model_selection import train_test_split

x_train, x_test , y_train , y_test =   train_test_split(df.drop('purchased',axis=1),
                 df['purchased'],test_size=0.2)

# %%
x_train
# Out:
#      review education
# 34  Average    School
# 14     Poor        PG
# 46     Poor        PG
# 16     Poor        UG
# 37  Average        PG
# 30  Average        UG
# 11     Good        UG
# 8   Average        UG
# 2      Good        PG
# 49     Good        UG
# 33     Good        PG
# 0   Average    School
# 12     Poor    School
# 42     Good        PG
# 5   Average    School
# 22     Poor        PG
# 48     Good        UG
# 7      Poor    School
# 36     Good        UG
# 13  Average    School
# 47     Good        PG
# 38     Good    School
# 19     Poor        PG
# 6      Good    School
# 31     Poor    School
# 35     Poor    School
# 27     Poor        PG
# 25     Good    School
# 24  Average        PG
# 41     Good        PG
# 40     Good    School
# 44  Average        UG
# 29  Average        UG
# 21  Average        PG
# 18     Good    School
# 17     Poor        UG
# 1      Poor        UG
# 28     Poor    School
# 23     Good    School
# 26     Poor        PG

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
OE = OrdinalEncoder(categories=[['Poor','Average','Good'],['School','UG','PG']])

# %%
OE.fit(x_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 OE.fit(x_train)
#
# File c:\Users\eurika\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\eurika\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:1496, in OrdinalEncoder.fit(self, X, y)
#    1489     raise TypeError(
#    1490         "unknown_value should only be set when "
#    1491         "handle_unknown is 'use_encoded_value', "
#    1492         f"got {self.unknown_value}."
#    1493     )
#    1495 # `_fit` will only raise an error when `self.handle_unknown="error"`
# -> 1496 fit_results = self._fit(
#    1497     X,
#    1498     handle_unknown=self.handle_unknown,
#    1499     force_all_finite="allow-nan",
#    1500     return_and_ignore_missing_for_infrequent=True,
#    1501 )
#    1502 self._missing_indices = fit_results["missing_indices"]
#    1504 cardinalities = [len(categories) for categories in self.categories_]
#
# File c:\Users\eurika\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:114, in _BaseEncoder._fit(self, X, handle_unknown, force_all_finite, return_counts, return_and_ignore_missing_for_infrequent)
#     111 else:
#     112     Xi_dtype = Xi.dtype
# --> 114 cats = np.array(self.categories[i], dtype=Xi_dtype)
#     115 if (
#     116     cats.dtype == object
#     117     and isinstance(cats[0], bytes)
#     118     and Xi.dtype.kind != "S"
#     119 ):
#     120     msg = (
#     121         f"In column {i}, the predefined categories have type 'bytes'"
#     122         " which is incompatible with values of type"
#     123         f" '{type(Xi[0]).__name__}'."
#     124     )
#
# ValueError: could not convert string to float: 'Poor'

# %%
x_train = OE.transform(x_train)
x_test = OE.transform(x_test)

# %%
x_train
# Out:
# array([[0., 1.],
#        [2., 0.],
#        [2., 0.],
#        [2., 2.],
#        [0., 0.],
#        [0., 2.],
#        [1., 2.],
#        [0., 2.],
#        [1., 0.],
#        [1., 2.],
#        [1., 0.],
#        [0., 1.],
#        [2., 1.],
#        [1., 0.],
#        [0., 1.],
#        [2., 0.],
#        [1., 2.],
#        [2., 1.],
#        [1., 2.],
#        [0., 1.],
#        [1., 0.],
#        [1., 1.],
#        [2., 0.],
#        [1., 1.],
#        [2., 1.],
#        [2., 1.],
#        [2., 0.],
#        [1., 1.],
#        [0., 0.],
#        [1., 0.],
#        [1., 1.],
#        [0., 2.],
#        [0., 2.],
#        [0., 0.],
#        [1., 1.],
#        [2., 2.],
#        [2., 2.],
#        [2., 1.],
#        [1., 1.],
#        [2., 0.]])

# %%
x_train
# Out:
# array([[0., 1.],
#        [2., 0.],
#        [2., 0.],
#        [2., 2.],
#        [0., 0.],
#        [0., 2.],
#        [1., 2.],
#        [0., 2.],
#        [1., 0.],
#        [1., 2.],
#        [1., 0.],
#        [0., 1.],
#        [2., 1.],
#        [1., 0.],
#        [0., 1.],
#        [2., 0.],
#        [1., 2.],
#        [2., 1.],
#        [1., 2.],
#        [0., 1.],
#        [1., 0.],
#        [1., 1.],
#        [2., 0.],
#        [1., 1.],
#        [2., 1.],
#        [2., 1.],
#        [2., 0.],
#        [1., 1.],
#        [0., 0.],
#        [1., 0.],
#        [1., 1.],
#        [0., 2.],
#        [0., 2.],
#        [0., 0.],
#        [1., 1.],
#        [2., 2.],
#        [2., 2.],
#        [2., 1.],
#        [1., 1.],
#        [2., 0.]])
